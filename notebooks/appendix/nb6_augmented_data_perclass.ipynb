# %%
import numpy as np
import pandas as pd
import sys

sys.path.append('.')
from utils import paired_bootstrap, to_latex_table

print("Notebook 6: Ready to train EmoViS+CB on 19K dataset and compare to 16K.")
# Training loop logic for the 19K dataset would go here...
